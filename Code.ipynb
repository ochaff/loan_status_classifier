# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import sklearn as sklearn

# %%
raw_data = pd.read_csv('./archive/Loan_status_2007-2020Q3.csv', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 raw_data = pd.read_csv('./archive/Loan_status_2007-2020Q3.csv', low_memory=False)
#
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = raw_data.copy()
df.drop(columns=['Unnamed: 0','url','id','zip_code','title','emp_title','inq_fi','mths_since_recent_inq', 'inq_last_6mths'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = raw_data.copy()
#       2 df.drop(columns=['Unnamed: 0','url','id','zip_code','title','emp_title','inq_fi','mths_since_recent_inq', 'inq_last_6mths'], inplace = True)
#
# NameError: name 'raw_data' is not defined

# %%
df.loc[df['loan_status'] == ('Fully Paid' or 'Charged Off')]
df.isnull().mean().sort_values(ascending = False, axis = 0)*100
df.dropna(axis = 1, thresh= (1-0.5)*len(df.index), inplace= True)

# %%
df
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           5000.0       5000.0           4975.0   36 months   10.65%
# 1           2500.0       2500.0           2500.0   60 months   15.27%
# 2           2400.0       2400.0           2400.0   36 months   15.96%
# 3          10000.0      10000.0          10000.0   36 months   13.49%
# 4           3000.0       3000.0           3000.0   60 months   12.69%
# ...            ...          ...              ...         ...      ...
# 2925488    24000.0      24000.0          24000.0   60 months   23.99%
# 2925489    10000.0      10000.0          10000.0   36 months    7.99%
# 2925490    10050.0      10050.0          10050.0   36 months   16.99%
# 2925491     6000.0       6000.0           6000.0   36 months   11.44%
# 2925492    30000.0      30000.0          30000.0   60 months   25.49%
#
#          installment grade sub_grade emp_length home_ownership  ...  \
# ...
